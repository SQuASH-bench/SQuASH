# %% [markdown]
# ## SQuASH Integration into Custom QAS

# %% [markdown]
# In this notebook, we see on the example of reinfocement learning driven QAS method how to integrate the benchmark into the custom method. Similar to previous notebooks, we first ensure proper dependency loading.

# %%
# Suppress PyTorch Warnings and ensure proper dependency loading
import warnings
import os
import sys

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=UserWarning)
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..')) # Go two levels up from the notebook location to reach project root

if project_root not in sys.path:
    sys.path.insert(0, project_root)
print("Project root set to:", project_root)
# Out:
# Project root set to: C:\SQuASH

# %% [markdown]
# ## Import dependencies

# %%
import time
import numpy as np


from qiskit import transpile, qasm3, QuantumCircuit
from qiskit.quantum_info import state_fidelity
from qiskit.circuit import Parameter
from qiskit_aer import Aer

from scipy.optimize import minimize

from torch import optim


from benchmark.utils import load_gnn_benchmark_model
from benchmark.search_spaces.ghz_a.generate_target_ghz_a import get_ghz_a_target
from benchmark.utils import predict_circuit_performance, convert_qasm_circuit_into_trainable_pqc
from benchmark.tutorials.rl_utils import (
    get_all_parametrized_one_q_qates,
    get_parametrized_controlled_two_q_gates,
    get_parametrized_uncontrolled_two_q_gates, 
    split_gate_set, get_num_actions_from_gate_set_and_layers,
    get_exec_time, set_seed, plot_results
)

# %% [markdown]
# ## 🌎 Defining the Environment

# %% [markdown]
# At its core, the **environment** simulates how an RL agent can construct a quantum circuit gate by gate, with the goal of generating a target quantum state as accurately and efficiently as possible.

# %% [markdown]
# The goal of the agent is to construct quantum circuits that prepare a specific target quantum state — in this case, the three-qubit GHZ state, defined as:
# $$
# |\text{GHZ}_3\rangle = \frac{1}{\sqrt{2}}(|000\rangle + |111\rangle)
# $$
# To achieve this, the agent interacts with an environment modeled as a (parametrized) quantum circuit. Here, the design of the environment is defined by the search space `ghz_a`. At each discrete time step $t$, the agent selects an **action $a_t \in A$, which corresponds to applying a quantum gate from the allowed gate set:
# $$
# \mathcal{G}_{\text{ghz\_a}} = \{\text{cx}, \text{h}, \text{rx}, \text{ry}, \text{rz}, \text{id}\}
# $$
#
# This action is applied to the circuit, modifying the current quantum state $|\psi_t\rangle \in \mathbb{C}^{2^n}$, where $𝑛=3$ is the number of qubits. The quantum state is updated according to the gate's operation and any parametrized rotation angles $\theta$.
#
# The environment observes the updated quantum state after each action. With this, the RL **state** $s_t \in S$ is represented by its statevector  $|\psi_t>$.

# %% [markdown]
# ### Reusable environment `QuantumCircuitEnv`

# %% [markdown]
# First, we define a broader environment `QuantumCircuitEnv`, which is reusable for different tasks. For this purpose, we use the `gymnasium` library.
#
# `QuantumCircuitEnv` is the class that provides all foundational logic for:
# - **Action Space $A$ Construction**
# It defines a discrete action space where each action corresponds to adding a specific gate (e.g., `h`, `rx`, `cx`) to specific qubits, possibly with parameters. Note that parametrized gates have the angle value 0 assigned to. Later, bevor the circuit is optimized, parameteres are reassigned uniformly in the range [-0.01, 0.01], which is conform to the search space `ghz_a`.
# - **Observation Space $S$**
# The observation is a statevector representation of the current quantum state, split into real and imaginary parts.
#
# - **Gate Cache System**
# We precompute a mapping of valid gate/qubit/parameter combinations to action indices, so action decoding is efficient.
#
# - **Circuit Construction Logic**
# The environment keeps track of the circuit under construction and updates it step-by-step based on agent actions.
#
# - **Reward Evaluation $R$**
# This base class is generic and leaves reward computation to the task passed during initialization.

# %%
#!pip install gymnasium==0.29.1
#!pip install stable_baselines3==2.5.0

# %%
import gymnasium as gym
from gymnasium import spaces


class QuantumCircuitEnv(gym.Env):
    def __init__(self, task, gate_set, layer_set, num_qubits=3, seed=None, start_time=None):
        super().__init__()
        self.task = task
        self.gate_set = gate_set
        self.layer_set = layer_set
        self.num_qubits = num_qubits
        self.seed = seed
        self.start_time = start_time

        # Split gate set into categories
        (self.one_q_unparam_gates,
         self.one_q_param_gates,
         self.unparam_uncont_two_qubit_gates,
         self.unparam_cont_two_qubit_gates,
         self.param_uncont_two_qubit_gates,
         self.param_cont_two_qubit_gates) = split_gate_set(gate_set)

        self._init_environment()

    def _init_environment(self):
        self.current_step = 0
        self.global_step = 0
        self.total_reward = 0.0
        self.reward_list = []
        self.time_reward_log = []
        self.action_cache = {}

        num_actions = get_num_actions_from_gate_set_and_layers(self.gate_set, self.layer_set, self.num_qubits)
        self.action_space = spaces.Discrete(num_actions)
        self.observation_space = spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(2 ** (self.num_qubits + 1),),
            dtype=np.float64
        )
        self.state = np.zeros(2 ** self.num_qubits * 2, dtype=np.float64)
        self.circuit = QuantumCircuit(self.num_qubits)

    def reset(self, seed=None, options=None):
        super().reset(seed=self.seed)
        self.current_step = 0
        self.total_reward = 0.0
        self.circuit = QuantumCircuit(self.num_qubits)
        self.state = np.zeros(2 ** self.num_qubits * 2, dtype=np.float64)
        return self.state, {}

    def _add_to_cache(self, gate_list, qubit_pairs, param=None):
        for gate in gate_list:
            for qubits in qubit_pairs:
                self.action_cache[self._action_counter] = (gate, qubits, param)
                self._action_counter += 1

    def _qubit_combinations(self, with_control=False, param=False):
        combos = []
        for q1 in range(self.num_qubits - 1):
            for q2 in range(q1 + 1, self.num_qubits):
                combos.append([q1, q2])
                if with_control:
                    combos.append([q2, q1])
        return combos

    def _populate_cache(self):
        self._action_counter = 0
        self._add_to_cache(self.one_q_unparam_gates, [[q] for q in range(self.num_qubits)])
        self._add_to_cache(self.one_q_param_gates, [[q] for q in range(self.num_qubits)], param=0)
        self._add_to_cache(self.unparam_uncont_two_qubit_gates, self._qubit_combinations())
        self._add_to_cache(self.param_uncont_two_qubit_gates, self._qubit_combinations(), param=0)
        self._add_to_cache(self.unparam_cont_two_qubit_gates, self._qubit_combinations(with_control=True))
        self._add_to_cache(self.param_cont_two_qubit_gates, self._qubit_combinations(with_control=True), param=0)

    def _convert_gates(self, gate, qubits, param):
        pass

    def _convert_parametrized_layer(self, layer_name, param):
        pass

    def _convert_action(self, action):
        pass

    def step(self, action, train=True, random=False):
        pass

    def render(self, mode='human'):
        pass

    def get_info_and_simulator(self):
        return {}, Aer.get_backend('statevector_simulator')

# %% [markdown]
# ### Environment `StatePreparationEnvironmentTrainable`

# %% [markdown]
# Now, we specify the `StatePreparationEnvironmentTrainable`,  which extends `QuantumCircuitEnv` with domain-specific logic for GHZ state preparation tasks. Main enhancements include:
#
# - **Integration of a Surrogate Model**
# Optionally, it can evaluate circuits using a learned GNN-based surrogate model for fast reward prediction, instead of full simulation.
#
# - **Reward Mechanism**
# The environment computes a reward based on how close the constructed quantum circuit comes to the desired quantum state. A higher reward means a better match. The environment uses a `task` (see below) object to compare the prepared state with a target state and compute fidelity and return the reward based on the fidelity value.
#
# -  **Monitoring**
# Every few hundred steps, the environment logs average performance. When an episode ends, the system records logt, so we can monitor learning progress.

# %%
class StatePreparationEnvironmentTrainable(QuantumCircuitEnv):
    def __init__(self, task, gate_set, layer_set=[], num_qubits=3, seed=None, start_time=None):
        super().__init__(task, gate_set, layer_set, num_qubits, seed, start_time)
        self.predictor = None
        self.proxy = False
        self.num_parameters = 0

    def init_predictor(self, search_space, model_name, proxy):
        self.predictor = load_gnn_benchmark_model(model_name, search_space=search_space, device="cpu")
        self.proxy = proxy

    def get_new_param(self):
        param_name = f'θ{self.num_parameters}'
        self.num_parameters += 1
        return Parameter(param_name)

    def _is_parametrized_gate(self, gate):
        return gate in (
            get_all_parametrized_one_q_qates() +
            get_parametrized_controlled_two_q_gates() +
            get_parametrized_uncontrolled_two_q_gates()
        )

    def _convert_gates(self, gate, qubits, param):
        if self._is_parametrized_gate(gate):
            theta = self.get_new_param()
            getattr(self.circuit, gate)(theta, *qubits)
        else:
            getattr(self.circuit, gate)(*qubits)

    def _convert_action(self, action):
        if not self.action_cache:
            self._populate_cache()

        if action not in self.action_cache:
            raise ValueError(f"Action {action} is illegal.")

        gate, qubits, param = self.action_cache[action]
        self._convert_gates(gate, qubits, param)

    def step(self, action, train=True, random=False):
        self._convert_action(action)
        if action is None:
            print(f"[ERROR] Invalid action: {action}")
        info, simulator = self.get_info_and_simulator()
        info["circuit"] = self.circuit.copy()
        reward, done, fidelity, statevector = self.task.compute_reward(
            self.circuit, train=train, predictor=self.predictor, proxy=self.proxy
        )

        self.state = np.concatenate([statevector.data.real, statevector.data.imag])
        info["fidelity"] = fidelity
        self.total_reward += reward

        if done:
            self._handle_episode_end(info, train, random)

        if self.global_step > 0 and self.global_step % 300 == 0:
            self._log_performance()

        self.current_step += 1
        self.global_step += 1
        return self.state, reward, done, done, info

    def _handle_episode_end(self, info, train, random):
        self.num_parameters = 0
        self.reward_list.append(self.total_reward)
        elapsed_time = (time.time() - self.start_time) / 60.0
        self.time_reward_log.append(elapsed_time)
        self.total_reward = 0.0
        self.state, _ = self.reset()

    def _log_performance(self):
        print(f"{self.global_step} steps are finished.")
        last_rewards = self.reward_list[-300:]
        if last_rewards:
            mean_reward = sum(last_rewards) / len(last_rewards)
            print(f"Mean episode reward: {mean_reward}")

# %% [markdown]
#  ## ✏️ Defining the Task Class

# %% [markdown]
# To interact with our custom `GHZTaskTrainable`  Gym environment, we need to define a task. A task encapsulates everything that makes the problem meaningful and solvable, from generating target state to computing rewards for a given quantum circuit.
#
# >**🔗 Benchmark Integration**
# >A key component of the benchmark is the ability to evaluate a quantum circuit using a learned performance predictor. The following line shows how we >compute the predicted fidelity of a circuit:
# >```
# >optimal_fidelity = predict_circuit_performance(qasm3.dumps(self.bound_circuit),
# >                                                            model=predictor,
# >                                                            gate_set=ghz_a_conf["gate_set"],
# >                                                            proxy=proxy)
# >````
# >This prediction allows the agent to get fast, approximate feedback, dramatically speeding up training compared to full training.

# %%
class GHZTaskTrainable():
    def __init__(self, name, num_qubits: int = None):
        print(f"Initialize {name} task")
        self.num_qubits = num_qubits
        self.target_statevector = get_ghz_a_target()
        self.circuit_id = 0
        self.bound_circuit = None
        self.statevector = None
        self.depth = None

    @staticmethod
    def get_reward_return(fidelity: float = None, circuit_depth: int = None, statevector=None):
        if fidelity >= 0.95 or circuit_depth >= ghz_a_conf["max_depth"]:
            return fidelity, True, fidelity, statevector
        else:
            return -0.1, False, fidelity, statevector

    def optimize(self, circuit):
        initial_param_min = ghz_a_conf["initial_param_min"]
        initial_param_max = ghz_a_conf["initial_param_max"]
        optimizer = ghz_a_conf["optimizer"]
        max_iter = ghz_a_conf["optimizer_maxiter"]
        optimal_fidelity = None
        initial_params = np.random.uniform(initial_param_min, initial_param_max, len(circuit.parameters))
        bounds = [(-np.pi, np.pi)] * len(circuit.parameters) if circuit.parameters else None

        def fidelity_loss(params):
            param_dict = dict(zip(circuit.parameters, params))
            if params.__sizeof__() > 0:
                self.bound_circuit = circuit.assign_parameters(param_dict)
            else:
                self.bound_circuit = circuit
            self.depth = self.bound_circuit.depth()    
            backend = Aer.get_backend('statevector_simulator')
            transpiled_circuit = transpile(self.bound_circuit, backend)
            job = backend.run(transpiled_circuit)
            job_result = job.result()
            self.statevector = job_result.get_statevector()
            fidelity = state_fidelity(self.statevector, self.target_statevector)
            return -fidelity

        if circuit.parameters:
            try:
                result = minimize(fidelity_loss,
                                  initial_params,
                                  method=optimizer,
                                  options={'maxiter': max_iter},
                                  bounds=bounds)
                optimal_fidelity = result.fun
            except Exception as e:
                print(f"[ERROR] Optimization failed:{e}")
                print(circuit.draw())
        else:
            optimal_fidelity = fidelity_loss(initial_params)
        return optimal_fidelity, self.depth

    def compute_reward(self, circuit: QuantumCircuit = None, train=True, predictor=None, proxy=None):
        if predictor and (train):
            initial_param_min = ghz_a_conf["initial_param_min"]
            initial_param_max = ghz_a_conf["initial_param_max"]
            initial_params = np.random.uniform(initial_param_min, initial_param_max, len(circuit.parameters))
            param_dict = dict(zip(circuit.parameters, initial_params))
            if initial_params.__sizeof__() > 0:
                self.bound_circuit = circuit.assign_parameters(param_dict)
            else:
                self.bound_circuit = circuit
            optimal_fidelity = -predict_circuit_performance(qasm3.dumps(self.bound_circuit),
                                                            model=predictor,
                                                            gate_set=ghz_a_conf["gate_set"],
                                                            proxy=proxy)
            circuit_depth = self.bound_circuit.depth()
            backend = Aer.get_backend('statevector_simulator')
            transpiled_circuit = transpile(self.bound_circuit, backend)
            job = backend.run(transpiled_circuit)
            job_result = job.result()
            self.statevector = job_result.get_statevector()
        else:
            optimal_fidelity, circuit_depth = self.optimize(circuit)
            if optimal_fidelity >= 0.9:
                logger.info(circuit.draw())
                logger.info(f"Optimal Fidelity:{optimal_fidelity}", )
        return self.get_reward_return(-optimal_fidelity, circuit_depth, self.statevector)

# %% [markdown]
# # Train the agent
#
# Let´s start training!

# %%
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import DQN

class LossLoggingCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(LossLoggingCallback, self).__init__(verbose)
        self.policy_loss = []
        self.value_loss = []
        self.loss_history = []

    def _on_step(self) -> bool:
        policy_loss = self.model.logger.name_to_value.get("train/policy_gradient_loss", None)
        value_loss = self.model.logger.name_to_value.get("train/value_loss", None)
        loss = self.model.logger.name_to_value.get("train/loss", None)

        if policy_loss is not None:
            self.policy_loss.append(policy_loss)
        if value_loss is not None:
            self.value_loss.append(value_loss)
        if loss is not None:
            self.loss_history.append(loss)
        return True

# %%
def create_env(ghz_a_conf, seed, start_time=None, predictor=False, model_name=None):
    task = GHZTaskTrainable(name="state preparation ghz 3 qubits", num_qubits=ghz_a_conf["num_qubits"])
    env = StatePreparationEnvironmentTrainable(task=task, num_qubits=ghz_a_conf["num_qubits"],
                                                   gate_set=ghz_a_conf["gate_set"], 
                                                   seed=seed, start_time=start_time)
    env.predictor = predictor
    if env.predictor:
        env.init_predictor(search_space="ghz_a", model_name="gcn_augmented_ghz_a", proxy=False)
    env.action_space.seed(seed)
    return env

def train_agent(env, model_name, total_timesteps, seed):
    env.global_step = 0
    env.reward_list = []
    start_time = time.time()
    print(f"Start training of the DQN model.")
    policy_kwargs = dict(optimizer_class=optim.Adam, normalize_images=False)
    model_ = model_name(policy="MlpPolicy", env=env,
                        seed=seed,
                        device="cpu",
                        learning_rate=0.0003, policy_kwargs=policy_kwargs)
    callback_ = LossLoggingCallback()
    model_.learn(total_timesteps=total_timesteps, callback=callback_, progress_bar=False)
    loss = callback_.loss_history
    reward_list = env.reward_list
    end_time = time.time()
    execution_time_minutes = (end_time - start_time) / 60
    print(f"Training execution time: {execution_time_minutes:.4f} minutes")
    #model_.save("DQN_ghz_a")
    return model_, loss, reward_list

def start_experiment(total_timesteps, start_time, seed=None):
    if seed is not None:
        set_seed(seed)
    model_class = DQN
    rl_model, loss, reward_list = train_agent(env, model_class, total_timesteps=total_timesteps, seed=seed)
    end_time = time.time()
    exec_time = get_exec_time(start_time, end_time)
    print(f"Execution time: {exec_time[0]} h: {exec_time[1]} m: {exec_time[2]} s")
    return rl_model, np.array(loss), reward_list

# %%
from benchmark.search_spaces.ghz_a.ghz_a_search_space_config import ghz_a_conf

seed = 40
start_time = time.time()
predictor_model_name="gcn_augmented_ghz_a"
env = create_env(ghz_a_conf, seed=seed, start_time=start_time,  predictor=True, model_name=predictor_model_name)
total_timesteps = 25000

rl_model, loss_history, rewards_history = start_experiment(total_timesteps, start_time, seed)
plot_results(loss_history, rewards_history)
# Out:
# Initialize state preparation ghz 3 qubits task
# Num actions 21
# Start training of the DQN model.
# 300 steps are finished.
# Mean episode reward: -0.39628531529057404
# 600 steps are finished.
# Mean episode reward: -0.32506699496332336
# 900 steps are finished.
# Mean episode reward: -0.34515940041518706
# 1200 steps are finished.
# Mean episode reward: -0.3195855919953807
# 1500 steps are finished.
# Mean episode reward: -0.266847964722843
# 1800 steps are finished.
# Mean episode reward: -0.2512940868279825
# 2100 steps are finished.
# Mean episode reward: -0.22756696690212652
# 2400 steps are finished.
# Mean episode reward: -0.1865873818596209
# 2700 steps are finished.
# Mean episode reward: -0.1484263088206454
# 3000 steps are finished.
# Mean episode reward: -0.12477856747309396
# 3300 steps are finished.
# Mean episode reward: -0.12146683599551548
# 3600 steps are finished.
# Mean episode reward: -0.12925770172476794
# 3900 steps are finished.
# Mean episode reward: -0.09929519304633161
# 4200 steps are finished.
# Mean episode reward: -0.09528992610176427
# 4500 steps are finished.
# Mean episode reward: -0.10796566353241628
# 4800 steps are finished.
# Mean episode reward: -0.1279698318938418
# 5100 steps are finished.
# Mean episode reward: -0.13500287677844391
# 5400 steps are finished.
# Mean episode reward: -0.13867233146230407
# 5700 steps are finished.
# Mean episode reward: -0.16801502491037076
# 6000 steps are finished.
# Mean episode reward: -0.20088080683350598
# 6300 steps are finished.
# Mean episode reward: -0.22035896677772238
# 6600 steps are finished.
# Mean episode reward: -0.20649737959106795
# 6900 steps are finished.
# Mean episode reward: -0.219993354568879
# 7200 steps are finished.
# Mean episode reward: -0.20866684208313654
# 7500 steps are finished.
# Mean episode reward: -0.1709393796920779
# 7800 steps are finished.
# Mean episode reward: -0.1668231991529468
# 8100 steps are finished.
# Mean episode reward: -0.1679092799425128
# 8400 steps are finished.
# Mean episode reward: -0.15968431650598874
# 8700 steps are finished.
# Mean episode reward: -0.15415831309556988
# 9000 steps are finished.
# Mean episode reward: -0.14348424751559907
# 9300 steps are finished.
# Mean episode reward: -0.15138325493534424
# 9600 steps are finished.
# Mean episode reward: -0.1419489889840287
# 9900 steps are finished.
# Mean episode reward: -0.1229277214308582
# 10200 steps are finished.
# Mean episode reward: -0.10203012115756688
# 10500 steps are finished.
# Mean episode reward: -0.09024903078873966
# 10800 steps are finished.
# Mean episode reward: -0.007152698636054921
# 11100 steps are finished.
# Mean episode reward: 0.03161305614312495
# 11400 steps are finished.
# Mean episode reward: 0.23103983702262207
# 11700 steps are finished.
# Mean episode reward: 0.23546793360511434
# 12000 steps are finished.
# Mean episode reward: 0.307616775701443
# 12300 steps are finished.
# Mean episode reward: 0.43410846721132523
# 12600 steps are finished.
# Mean episode reward: 0.49895598446329437
# 12900 steps are finished.
# Mean episode reward: 0.6291050020058965
# 13200 steps are finished.
# Mean episode reward: 0.6908633319338185
# 13500 steps are finished.
# Mean episode reward: 0.6352633236050623
# 13800 steps are finished.
# Mean episode reward: 0.6356859305302316
# 14100 steps are finished.
# Mean episode reward: 0.6475989577571569
# 14400 steps are finished.
# Mean episode reward: 0.7057042687336632
# 14700 steps are finished.
# Mean episode reward: 0.700215589046481
# 15000 steps are finished.
# Mean episode reward: 0.6980310918688802
# 15300 steps are finished.
# Mean episode reward: 0.7033566128810274
# 15600 steps are finished.
# Mean episode reward: 0.6664616570870103
# 15900 steps are finished.
# Mean episode reward: 0.6593040249943756
# 16200 steps are finished.
# Mean episode reward: 0.6339756204585256
# 16500 steps are finished.
# Mean episode reward: 0.6251080481906749
# 16800 steps are finished.
# Mean episode reward: 0.6654821189542635
# 17100 steps are finished.
# Mean episode reward: 0.6674738649030548
# 17400 steps are finished.
# Mean episode reward: 0.6911510805885022
# 17700 steps are finished.
# Mean episode reward: 0.7226239020029733
# 18000 steps are finished.
# Mean episode reward: 0.7315103249947262
# 18300 steps are finished.
# Mean episode reward: 0.7365580348968537
# 18600 steps are finished.
# Mean episode reward: 0.6976474786400819
# 18900 steps are finished.
# Mean episode reward: 0.7049577265481182
# 19200 steps are finished.
# Mean episode reward: 0.6859826684296156
# 19500 steps are finished.
# Mean episode reward: 0.6749671829243523
# 19800 steps are finished.
# Mean episode reward: 0.6592646596630435
# 20100 steps are finished.
# Mean episode reward: 0.6837410372495678
# 20400 steps are finished.
# Mean episode reward: 0.6157812307874385
# 20700 steps are finished.
# Mean episode reward: 0.6859963183701063
# 21000 steps are finished.
# Mean episode reward: 0.6935686856011575
# 21300 steps are finished.
# Mean episode reward: 0.740559876501563
# 21600 steps are finished.
# Mean episode reward: 0.7575113651156461
# 21900 steps are finished.
# Mean episode reward: 0.7593803951541613
# 22200 steps are finished.
# Mean episode reward: 0.7689610121448862
# 22500 steps are finished.
# Mean episode reward: 0.7756839914123251
# 22800 steps are finished.
# Mean episode reward: 0.7642372744480801
# 23100 steps are finished.
# Mean episode reward: 0.7633686060309441
# 23400 steps are finished.
# Mean episode reward: 0.7554128672083247
# 23700 steps are finished.
# Mean episode reward: 0.75925340420008
# 24000 steps are finished.
# Mean episode reward: 0.7605526781082181
# 24300 steps are finished.
# Mean episode reward: 0.7617655162215266
# 24600 steps are finished.
# Mean episode reward: 0.7573450710574818
# 24900 steps are finished.
# Mean episode reward: 0.757327120383584
# Training execution time: 52.4476 minutes
# Execution time: 0 h: 52 m: 28 s

# %% [markdown]
# Now, we test the trained model and evaluate the generated circuit regarding its predicted and ground thruth performace.

# %%
from benchmark.search_spaces.ghz_a.evaluate_circuit_ghz_a import get_performance

def test_agent(env, rl_model, seed):
    print("Test agent")
    obs, info = env.reset()
    #dqn = DQN.load("A2C_ghz_a", env=env)
    while True:
        action, _states = rl_model.predict(obs, deterministic=False)
        obs, reward, done, truncated, info = env.step(int(action), train=True)
        if done or truncated:
            print(f"Total reward:{env.total_reward}")
            print("''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''")
            print(f"Generated circuit: {info['circuit'].draw()}")
            print(f"Predicted performance:{reward}")
            
            def fidelity_loss(params):
                param_dict = dict(zip(trainable_circuit.parameters, params))
                if params.__sizeof__() > 0:
                    bound_circuit = trainable_circuit.assign_parameters(param_dict)
                else:
                    bound_circuit = trainable_circuit
                fidelity = get_performance(bound_circuit)
                return -fidelity
            
            
            def minimize_circ(circuit, params, search_space_config):
                initial_params = params
                bounds = [(search_space_config["optimizer_bound_min"], search_space_config["optimizer_bound_max"])] * len(
                    circuit.parameters) if circuit.parameters else None
                if circuit.parameters:
                    result = minimize(fidelity_loss,
                                      initial_params,
                                      method=search_space_config["optimizer"],
                                      options={'maxiter': search_space_config["optimizer_maxiter"]},
                                      bounds=bounds)
                    optimal_fidelity = result.fun
                    optimal_params = result.x
                    param_dict = dict(zip(circuit.parameters, optimal_params))
                    optimal_circuit = circuit.assign_parameters(param_dict)
                else:
                    optimal_fidelity = get_performance(circuit)
                    optimal_circuit = circuit
                return optimal_fidelity,optimal_circuit
            
            
    
            trainable_circuit, params = convert_qasm_circuit_into_trainable_pqc(qasm3.dumps(info['circuit']), num_qubits=env.num_qubits)
            ground_truth_fidelity_after_training, optimized_circuit = minimize_circ(trainable_circuit, params,
                                                                                ghz_a_conf)
            print("''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''")
            print(f"Ground truth performance for the trained PQC: {ground_truth_fidelity_after_training}")
            print("Ground truth optimized circuit", {optimized_circuit.draw()})
            break
    env.render()

# %%
test_agent(env, rl_model, seed)
# Out:
# Test agent
# Total reward:0.0
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
# Generated circuit:                ┌───┐
# q_0: ──────────┤ X ├
#           ┌───┐└─┬─┘
# q_1: ─────┤ X ├──■──
#      ┌───┐└─┬─┘
# q_2: ┤ H ├──■───────
#      └───┘
# Predicted performance:1.0
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
# Ground truth performance for the trained PQC: 1.0000000000000004
# Ground truth optimized circuit {               ┌───┐
# q_0: ──────────┤ X ├
#           ┌───┐└─┬─┘
# q_1: ─────┤ X ├──■──
#      ┌───┐└─┬─┘
# q_2: ┤ H ├──■───────
#      └───┘          }

# %%
env = create_env(ghz_a_conf, seed=1837, start_time=start_time,  predictor=True, model_name=predictor_model_name)
test_agent(env, rl_model, seed=1837)
# Out:
# Initialize state preparation ghz 3 qubits task
# Num actions 21
# Test agent
# Total reward:0.0
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
# Generated circuit:                ┌───┐
# q_0: ──────────┤ X ├
#           ┌───┐└─┬─┘
# q_1: ─────┤ X ├──■──
#      ┌───┐└─┬─┘
# q_2: ┤ H ├──■───────
#      └───┘
# Predicted performance:1.0
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
# Ground truth performance for the trained PQC: 1.0000000000000004
# Ground truth optimized circuit {               ┌───┐
# q_0: ──────────┤ X ├
#           ┌───┐└─┬─┘
# q_1: ─────┤ X ├──■──
#      ┌───┐└─┬─┘
# q_2: ┤ H ├──■───────
#      └───┘          }

# %%
env = create_env(ghz_a_conf, seed=234, start_time=start_time,  predictor=True, model_name=predictor_model_name)
test_agent(env, rl_model, seed=234)
# Out:
# Initialize state preparation ghz 3 qubits task
# Num actions 21
# Test agent
# Total reward:0.0
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
# Generated circuit:                ┌───┐
# q_0: ──────────┤ X ├
#           ┌───┐└─┬─┘
# q_1: ─────┤ X ├──■──
#      ┌───┐└─┬─┘
# q_2: ┤ H ├──■───────
#      └───┘
# Predicted performance:1.0
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
# Ground truth performance for the trained PQC: 1.0000000000000004
# Ground truth optimized circuit {               ┌───┐
# q_0: ──────────┤ X ├
#           ┌───┐└─┬─┘
# q_1: ─────┤ X ├──■──
#      ┌───┐└─┬─┘
# q_2: ┤ H ├──■───────
#      └───┘          }

# %% [markdown]
# The generated quantum circuit successfully produces the desired target state.

# %% [markdown]
# ## Execution without surrogate model - true circuit evaluation
# Let´s execute the algorithm **with true evaluation** to confirm the results.

# %%
from benchmark.search_spaces.ghz_a.ghz_a_search_space_config import ghz_a_conf

seed = 40
start_time = time.time()
env = create_env(ghz_a_conf, seed=seed, start_time=start_time,  predictor=False)
total_timesteps = 25000

rl_model, loss_history, rewards_history = start_experiment(total_timesteps, start_time, seed)
plot_results(loss_history, rewards_history)
# Out:
# Initialize state preparation ghz 3 qubits task
# Num actions 21
# Start training of the DQN model.
# 300 steps are finished.
# Mean episode reward: -0.39758065027220224
# 600 steps are finished.
# Mean episode reward: -0.34772727568364425
# 900 steps are finished.
# Mean episode reward: -0.33050000250641565
# 1200 steps are finished.
# Mean episode reward: -0.31518518750118235
# 1500 steps are finished.
# Mean episode reward: -0.27261236148292967
# 1800 steps are finished.
# Mean episode reward: -0.24772727443722573
# 2100 steps are finished.
# Mean episode reward: -0.13731884203515904
# 2400 steps are finished.
# Mean episode reward: -0.10500000090929748
# 2700 steps are finished.
# Mean episode reward: -0.07133333420571339
# 3000 steps are finished.
# Mean episode reward: -0.03983333397620575
# 3300 steps are finished.
# Mean episode reward: -0.025416667189144745
# 3600 steps are finished.
# Mean episode reward: -0.008333333750650117
# 3900 steps are finished.
# Mean episode reward: -0.04000000034568167
# 4200 steps are finished.
# Mean episode reward: -0.06633333363277231
# 4500 steps are finished.
# Mean episode reward: -0.07183333356428036
# 4800 steps are finished.
# Mean episode reward: 0.027666666404664333
# 5100 steps are finished.
# Mean episode reward: 0.10133333312113006
# 5400 steps are finished.
# Mean episode reward: 0.0956666664348192
# 5700 steps are finished.
# Mean episode reward: 0.08499999965524421
# 6000 steps are finished.
# Mean episode reward: 0.06183333298621098
# 6300 steps are finished.
# Mean episode reward: 0.05966666624607972
# 6600 steps are finished.
# Mean episode reward: 0.02183333278348362
# 6900 steps are finished.
# Mean episode reward: -0.10250000066932564
# 7200 steps are finished.
# Mean episode reward: -0.09783333404833319
# 7500 steps are finished.
# Mean episode reward: -0.10341666741872542
# 7800 steps are finished.
# Mean episode reward: -0.12058333410896639
# 8100 steps are finished.
# Mean episode reward: -0.13975000076525057
# 8400 steps are finished.
# Mean episode reward: -0.13791666723973822
# 8700 steps are finished.
# Mean episode reward: -0.16158333381131113
# 9000 steps are finished.
# Mean episode reward: -0.17491666708246237
# 9300 steps are finished.
# Mean episode reward: -0.20375000050279232
# 9600 steps are finished.
# Mean episode reward: -0.22916666711741826
# 9900 steps are finished.
# Mean episode reward: -0.21808333372509162
# 10200 steps are finished.
# Mean episode reward: -0.21091666706248507
# 10500 steps are finished.
# Mean episode reward: -0.1920833337167684
# 10800 steps are finished.
# Mean episode reward: -0.15708333368342417
# 11100 steps are finished.
# Mean episode reward: -0.13241666699373109
# 11400 steps are finished.
# Mean episode reward: -0.0832500002160247
# 11700 steps are finished.
# Mean episode reward: -0.03991666679225728
# 12000 steps are finished.
# Mean episode reward: -0.0038333335475659023
# 12300 steps are finished.
# Mean episode reward: -0.01333333361740675
# 12600 steps are finished.
# Mean episode reward: -0.014333333767070565
# 12900 steps are finished.
# Mean episode reward: -0.022500000417883168
# 13200 steps are finished.
# Mean episode reward: -0.028500000441436663
# 13500 steps are finished.
# Mean episode reward: -0.036833333778735954
# 13800 steps are finished.
# Mean episode reward: -0.03633333378640911
# 14100 steps are finished.
# Mean episode reward: -0.029000000398749944
# 14400 steps are finished.
# Mean episode reward: -0.03333333370646035
# 14700 steps are finished.
# Mean episode reward: -0.023166667058018606
# 15000 steps are finished.
# Mean episode reward: -0.017666667040993473
# 15300 steps are finished.
# Mean episode reward: -0.007166667034390922
# 15600 steps are finished.
# Mean episode reward: 0.000166666306418799
# 15900 steps are finished.
# Mean episode reward: -0.007166667029543549
# 16200 steps are finished.
# Mean episode reward: -0.0015000003034027444
# 16500 steps are finished.
# Mean episode reward: 0.003999999689462424
# 16800 steps are finished.
# Mean episode reward: 0.005833332676019198
# 17100 steps are finished.
# Mean episode reward: -0.005166667550210883
# 17400 steps are finished.
# Mean episode reward: -0.0018333342415054802
# 17700 steps are finished.
# Mean episode reward: 0.003499999146679615
# 18000 steps are finished.
# Mean episode reward: 0.005333332422970105
# 18300 steps are finished.
# Mean episode reward: -0.000333334197486553
# 18600 steps are finished.
# Mean episode reward: -0.0005000006624038583
# 18900 steps are finished.
# Mean episode reward: 0.0028333328988059425
# 19200 steps are finished.
# Mean episode reward: 0.009666666250997297
# 19500 steps are finished.
# Mean episode reward: -0.001833333686957926
# 19800 steps are finished.
# Mean episode reward: -0.002166667058492347
# 20100 steps are finished.
# Mean episode reward: 0.030166666289820506
# 20400 steps are finished.
# Mean episode reward: 0.2646666664419798
# 20700 steps are finished.
# Mean episode reward: 0.5108333331277638
# 21000 steps are finished.
# Mean episode reward: 0.7558333332111576
# 21300 steps are finished.
# Mean episode reward: 0.7713333332250104
# 21600 steps are finished.
# Mean episode reward: 0.7639999998546253
# 21900 steps are finished.
# Mean episode reward: 0.7502499998148155
# 22200 steps are finished.
# Mean episode reward: 0.751083333192275
# 22500 steps are finished.
# Mean episode reward: 0.7473333332035951
# 22800 steps are finished.
# Mean episode reward: 0.7657499998987386
# 23100 steps are finished.
# Mean episode reward: 0.751499999807674
# 23400 steps are finished.
# Mean episode reward: 0.7554166664909497
# 23700 steps are finished.
# Mean episode reward: 0.7488333331473188
# 24000 steps are finished.
# Mean episode reward: 0.7494166665464299
# 24300 steps are finished.
# Mean episode reward: 0.7694166665348816
# 24600 steps are finished.
# Mean episode reward: 0.7602499998894349
# 24900 steps are finished.
# Mean episode reward: 0.7563333332393388
# Training execution time: 363.5479 minutes
# Execution time: 6 h: 3 m: 33 s

# %% [markdown]
# ## Result
#
# By leveraging a surrogate model during training, we significantly reduced the computation time:
#
# - **With surrogate model**:  52 minutes 28 seconds
#
# - **Without surrogate model**: 6 hours 3 minutes 33 seconds
#
# This demonstrates a **~6× speed-up** in training time, making the approach far more practical for iterative experiments and large-scale benchmarking.
