# %% [markdown]
# # GCN Model Evaluation

# %% [markdown]
# In this notebook, we will evaluate the trained in demo notebook `0 - train_gcn_surrogate_model_from_scratch.ipynb` GCN surrogate model for predicting the performance of quantum circuits on `ghz_a`.
# The evaluation involves loading the trained GCN model, evaluating its performance, and visualizing key metrics like the distribution of errors and fidelity predictions.

# %% [markdown]
# ## 1. Import Dependencies

# %% [markdown]
# First, we import the necessary dependencies for our evaluation.

# %%
# Suppress PyTorch Warnings and ensure proper dependency loading
import warnings
import os
import sys

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=UserWarning)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) # Go two levels up from the notebook location to reach project root

if project_root not in sys.path:
    sys.path.insert(0, project_root)
print("Project root set to:", project_root)
# Out:
# Project root set to: /Users/danielbarta/Desktop/work/FOKUS/SQuASH

# %%
from config import DeviceConfig, PathConfig,
from evaluate.evaluate_model import run_gcn_evaluation
from util.config_utils import get_gate_set_and_features_by_name

# %% [markdown]
# ## 2. Setup Configuration

# %% [markdown]
# We define paths and other configurations necessary for loading the model and dataset.

# %%
# Initialize device configuration and path configuration
device_config = DeviceConfig()
device = device_config.device
path_config = PathConfig()
color = 'skyblue'

# Define the gate set and dataset name
gate_set = 'gate_set_ghz_a'
data_set_name = 'test_ghz_a_squash'
model_name = 'gcn_demo_gcn_ghz_a_2025-04-19_15-14-17'

# Get gate set features
gate_mapping, _ = get_gate_set_and_features_by_name(gate_set)

# %% [markdown]
# ## 3. Load and Evaluate GCN Model

# %% [markdown]
# We now proceed to evaluate the GCN model, which includes loading the model, running the evaluation, and computing metrics such as fidelity and error.

# %%
metrics_gnn = run_gcn_evaluation(device=device, model_name=model_name, data_set_name=data_set_name, gate_mapping=gate_mapping, path_config=path_config, color=color)
# Out:
# === GNN Evaluation ===
# demo_gcn_ghz_a_2025-04-19_15-14-17
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/work/FOKUS/SQuASH/config.py:91, in get_model_config_from_path(model_config_path, device)
#      90 try:
# ---> 91     with open(model_config_path, 'r') as f:
#      92         config = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/danielbarta/Desktop/work/FOKUS/SQuASH/surrogate_models/trained_models/demo_gcn_ghz_a_2025-04-19_15-14-17/demo_gcn_ghz_a_2025-04-19_15-14-17_config.json'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 metrics_gnn = run_gcn_evaluation(device=device, model_name=model_name, data_set_name=data_set_name, gate_mapping=gate_mapping, path_config=path_config, color=color)
#
# File ~/Desktop/work/FOKUS/SQuASH/evaluate/evaluate_model.py:105, in run_gcn_evaluation(device, model_name, data_set_name, gate_mapping, color, path_config)
#     103 print(model_name)
#     104 model_config_path = os.path.join(path_config.paths['trained_models'], f'{model_name}', f'{model_name}_config.json')
# --> 105 model_config = get_model_config_from_path(model_config_path, device)
#     107 dataset_path = os.path.join(path_config.paths['gcn_data'], f'{data_set_name}.pt')
#     108 circuits = load_data(dataset_path)
#
# File ~/Desktop/work/FOKUS/SQuASH/config.py:100, in get_model_config_from_path(model_config_path, device)
#      98     return ModelConfig(**config)
#      99 except (FileNotFoundError, json.JSONDecodeError) as e:
# --> 100     raise RuntimeError(f"Failed to load model config from '{model_config_path}': {e}")
#
# RuntimeError: Failed to load model config from '/Users/danielbarta/Desktop/work/FOKUS/SQuASH/surrogate_models/trained_models/demo_gcn_ghz_a_2025-04-19_15-14-17/demo_gcn_ghz_a_2025-04-19_15-14-17_config.json': [Errno 2] No such file or directory: '/Users/danielbarta/Desktop/work/FOKUS/SQuASH/surrogate_models/trained_models/demo_gcn_ghz_a_2025-04-19_15-14-17/demo_gcn_ghz_a_2025-04-19_15-14-17_config.json'
